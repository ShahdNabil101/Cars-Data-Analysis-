# %%
! pip install pandas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cars = pd.read_csv('cars.csv')
cars.head()
# Out:
#    carID     brand      model  year transmission  mileage fuelType  tax   mpg  \
# 0  13207    hyundi   Santa Fe  2019    Semi-Auto   4223.0   Diesel  145  39.8
# 1  17314  vauxhall        GTC  2015       Manual  47870.0   Diesel  125  60.1
# 2  12342      audi        RS4  2019    Automatic   5151.0   Petrol  145  29.1
# 3  13426        vw   Scirocco  2016    Automatic  20423.0   Diesel   30  57.6
# 4  16004     skoda      Scala  2020    Semi-Auto   3569.0   Petrol  145  47.1
#
#    engineSize  price
# 0         2.2  31995
# 1         2.0   7700
# 2         2.9  58990
# 3         2.0  12999
# 4         1.0  16990

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4960 entries, 0 to 4959
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   carID         4960 non-null   int64
#  1   brand         4942 non-null   object
#  2   model         4960 non-null   object
#  3   year          4960 non-null   int64
#  4   transmission  4960 non-null   object
#  5   mileage       4954 non-null   float64
#  6   fuelType      4943 non-null   object
#  7   tax           4960 non-null   int64
#  8   mpg           4948 non-null   float64
#  9   engineSize    4952 non-null   float64
#  10  price         4960 non-null   int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 426.4+ KB

# %%
cars.isnull().sum()
# Out:
# carID            0
# brand           18
# model            0
# year             0
# transmission     0
# mileage          6
# fuelType        17
# tax              0
# mpg             12
# engineSize       8
# price            0
# dtype: int64

# %%
cars.duplicated().sum()
# Out:
# 0

# %%
cars.describe()
# Out:
#               carID         year        mileage          tax          mpg  \
# count   4960.000000  4960.000000    4954.000000  4960.000000  4948.000000
# mean   15832.446169  2016.737903   24949.957812   152.332661    50.390158
# std     2206.717006     2.884035   24451.380600    82.403844    35.781756
# min    12002.000000  1997.000000       1.000000     0.000000     2.800000
# 25%    13929.250000  2016.000000    5622.500000   145.000000    38.700000
# 50%    15840.000000  2017.000000   18971.500000   145.000000    47.100000
# 75%    17765.750000  2019.000000   36692.750000   150.000000    54.300000
# max    19629.000000  2020.000000  259000.000000   580.000000   470.800000
#
#         engineSize          price
# count  4952.000000    4960.000000
# mean      2.123425   23469.943750
# std       0.786778   16406.714563
# min       0.000000     450.000000
# 25%       1.600000   12000.000000
# 50%       2.000000   18999.000000
# 75%       2.800000   30335.750000
# ...

# %%
cars.describe(include = 'object')
# Out:
#        brand    model transmission fuelType
# count   4942     4960         4960     4943
# unique     9       90            4        5
# top     merc   Arteon       Manual   Diesel
# freq     789      167         1948     2981

# %%
cars['brand'].unique()
# Out:
# array(['hyundi', 'vauxhall', 'audi', 'vw', 'skoda', 'merc', 'toyota',
#        'bmw', 'ford', nan], dtype=object)

# %%
cars['model'].unique()
# Out:
# array([' Santa Fe', ' GTC', ' RS4', ' Scirocco', ' Scala', ' V Class',
#        ' Prius', ' M4', ' Camry', ' KA', ' Vivaro', ' CLS Class',
#        ' Caravelle', ' Arteon', ' Shuttle', ' I40', ' IX20', ' 6 Series',
#        ' GL Class', ' S Class', ' S3', ' Yeti', ' Galaxy', ' Puma',
#        ' Edge', ' A8', ' SLK', ' Kamiq', ' RS6', ' CLA Class',
#        ' Land Cruiser', ' M Class', ' Q8', ' i3', ' Verso', ' Mustang',
#        ' IX35', ' Amarok', ' Avensis', ' Grand Tourneo Connect',
#        ' Antara', ' Tourneo Connect', ' Beetle', ' X4', ' CC', ' GT86',
#        ' X-CLASS', ' I800', ' i8', ' Caddy Maxi Life', ' Combo Life',
#        ' Rapid', ' SQ7', ' Grand C-MAX', ' Tourneo Custom', ' California',
#        ' Agila', ' A7', ' Zafira Tourer', ' G Class', ' Tiguan Allspace',
#        ' X6', ' M2', ' X7', ' 7 Series', ' Z4', ' RS5', ' Hilux',
#        ' GLS Class', ' GLB Class', ' M5', ' RS3', ' Caddy Life', ' SQ5',
# ...

# %%
cars['year'].unique()
# Out:
# array([2019, 2015, 2016, 2020, 2012, 2018, 2017, 2009, 2013, 2006, 2011,
#        2014, 2008, 1997, 2001, 2010, 2005, 2004, 2007, 2000, 2003, 2002,
#        1999, 1998])

# %%
cars['transmission'].unique()
# Out:
# array(['Semi-Auto', 'Manual', 'Automatic', 'Other'], dtype=object)

# %%
cars['mileage'].unique()
# Out:
# array([ 4223., 47870.,  5151., ..., 24314., 84932., 30150.])

# %%
cars['fuelType'].unique()
# Out:
# array(['Diesel', 'Petrol', 'Hybrid', 'Other', 'Electric', nan],
#       dtype=object)

# %%
cars['tax'].unique()
# Out:
# array([145, 125,  30, 135, 160, 200,  20, 205, 325, 235, 150, 260,   0,
#        555, 290, 580, 265, 300, 305, 165, 315,  10, 240, 115, 330, 570,
#        565, 195, 535, 140, 280, 230, 155, 185, 270, 220, 540, 250, 515,
#        190, 245])

# %%
cars['brand'].value_counts()
# Out:
# brand
# merc        789
# vw          765
# ford        765
# bmw         635
# hyundi      507
# toyota      446
# skoda       421
# audi        342
# vauxhall    272
# Name: count, dtype: int64

# %%
cars['model'].value_counts()
# Out:
# model
# Arteon         167
# Grand C-MAX    164
# Scirocco       163
# Prius          154
# Santa Fe       150
#               ...
# Eos              5
# Z3               5
# Getz             4
# CLK              4
# IQ               2
# Name: count, Length: 90, dtype: int64

# %%
cars['year'].value_counts()
# Out:
# year
# 2019    1359
# 2017     816
# 2016     743
# 2018     534
# 2015     461
# 2020     337
# 2014     254
# 2013     181
# 2012      56
# 2011      51
# 2009      26
# 2010      25
# 2008      20
# 2004      18
# 2007      18
# 2006      15
# 2005      12
# 2003      10
# 2001       9
# 2002       6
# 1999       3
# 1997       2
# 2000       2
# 1998       2
# Name: count, dtype: int64

# %%
cars['fuelType'].value_counts()
# Out:
# fuelType
# Diesel      2981
# Petrol      1747
# Hybrid       187
# Other         26
# Electric       2
# Name: count, dtype: int64

# %%
cars['transmission'].value_counts()
# Out:
# transmission
# Manual       1948
# Automatic    1660
# Semi-Auto    1351
# Other           1
# Name: count, dtype: int64

# %%
cars['mileage'].value_counts()
# Out:
# mileage
# 1000.0     51
# 10.0       45
# 5000.0     37
# 3000.0     32
# 100.0      25
#            ..
# 23275.0     1
# 6205.0      1
# 12316.0     1
# 12855.0     1
# 30150.0     1
# Name: count, Length: 3895, dtype: int64

# %%
cars['mpg'].value_counts()
# Out:
# mpg
# 50.4    236
# 47.1    213
# 57.7    169
# 53.3    164
# 47.9    159
#        ...
# 28.2      1
# 19.1      1
# 20.5      1
# 18.9      1
# 48.0      1
# Name: count, Length: 125, dtype: int64

# %%
cars['engineSize'].value_counts()
# Out:
# engineSize
# 2.0    1288
# 3.0     937
# 1.5     327
# 1.6     284
# 1.2     283
# 1.0     268
# 2.1     245
# 1.8     230
# 2.2     210
# 1.4     199
# 2.5     112
# 1.7     110
# 2.9      84
# 2.3      60
# 4.0      56
# 4.4      40
# 2.4      35
# 0.0      34
# 5.0      30
# 2.8      24
# 5.2      17
# 4.2      16
# 3.2      11
# 5.5      11
# 1.3      11
# 0.6       6
# 3.5       6
# 1.9       4
# 4.7       3
# 2.7       2
# 1.1       2
# 6.0       2
# 6.2       1
# 4.3       1
# 3.7       1
# 4.5       1
# 6.6       1
# Name: count, dtype: int64

# %%
mil_mean = cars['mileage'].mean()

# %%
cars['mileage'].fillna(mil_mean,inplace = True)
# Out:
# <ipython-input-30-688c372c3ecb>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['mileage'].fillna(mil_mean,inplace = True)

# %%
mpg_mean = cars['mpg'].mean()

# %%
cars['mpg'].fillna(mpg_mean,inplace = True)
# Out:
# <ipython-input-32-5b7493561511>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['mpg'].fillna(mpg_mean,inplace = True)

# %%
eng_mean = cars['engineSize'].mean()

# %%
cars['engineSize'].fillna(eng_mean,inplace = True)
# Out:
# <ipython-input-34-055eed6d245b>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['engineSize'].fillna(eng_mean,inplace = True)

# %%
brand_mode = cars['brand'].mode()[0]

# %%
cars['brand'].fillna(brand_mode,inplace = True)
# Out:
# <ipython-input-36-5e33c45f72c9>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['brand'].fillna(brand_mode,inplace = True)

# %%
fulltype_mode = cars['fuelType'].mode()[0]

# %%
cars['fuelType'].fillna(fulltype_mode,inplace = True)
# Out:
# <ipython-input-38-637903c58d86>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars['fuelType'].fillna(fulltype_mode,inplace = True)

# %%
cars.isnull().sum()
# Out:
# carID           0
# brand           0
# model           0
# year            0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# price           0
# dtype: int64

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4960 entries, 0 to 4959
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   carID         4960 non-null   int64
#  1   brand         4960 non-null   object
#  2   model         4960 non-null   object
#  3   year          4960 non-null   int64
#  4   transmission  4960 non-null   object
#  5   mileage       4960 non-null   float64
#  6   fuelType      4960 non-null   object
#  7   tax           4960 non-null   int64
#  8   mpg           4960 non-null   float64
#  9   engineSize    4960 non-null   float64
#  10  price         4960 non-null   int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 426.4+ KB

# %%
cars['transmission'] = cars['transmission'].replace('Other','Manual')

# %%
cars['transmission'].unique()
# Out:
# array(['Semi-Auto', 'Manual', 'Automatic'], dtype=object)

# %%
cars['fuelType'] = cars['fuelType'].replace('Other','Diesel')

# %%
cars['fuelType'].unique()
# Out:
# array(['Diesel', 'Petrol', 'Hybrid', 'Electric'], dtype=object)

# %%
cars.drop('carID',axis = 1 ,inplace = True)

# %%
cars['total cost'] = cars['price'] + cars['tax']

# %%
cars.drop(['tax', 'price'],axis = 1, inplace = True)

# %%
cars['brand'].value_counts()
# Out:
# brand
# merc        807
# vw          765
# ford        765
# bmw         635
# hyundi      507
# toyota      446
# skoda       421
# audi        342
# vauxhall    272
# Name: count, dtype: int64

# %%
sns.countplot(data = cars, x = 'brand')
# Out:
# <Axes: xlabel='brand', ylabel='count'>

# %%
cars['model'].value_counts()
# Out:
# model
# Arteon         167
# Grand C-MAX    164
# Scirocco       163
# Prius          154
# Santa Fe       150
#               ...
# Eos              5
# Z3               5
# Getz             4
# CLK              4
# IQ               2
# Name: count, Length: 90, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=cars, x='year', palette='viridis')
plt.title('Distribution of Cars by Year', fontsize=16)
plt.xlabel('Year of Manufacture', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-104-f1d8e2f6cf57>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=cars, x='year', palette='viridis')
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.countplot(data = cars , x = 'transmission')
# Out:
# <Axes: xlabel='transmission', ylabel='count'>

# %%
sns.countplot(data = cars , x = 'fuelType')
# Out:
# <Axes: xlabel='fuelType', ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # تكبير حجم الرسم
sns.histplot(data=cars, x='total cost', kde=True, bins=30, color='skyblue')  # ضبط عدد الفئات (bins) واستخدام لون محدد
plt.title('Distribution of Total Cost', fontsize=16)  # إضافة عنوان
plt.xlabel('Total Cost', fontsize=12)  # تسمية المحور X
plt.ylabel('Frequency', fontsize=12)  # تسمية المحور Y
plt.xlim(cars['total cost'].min(), cars['total cost'].max())  # ضبط حدود المحور X إذا كان هناك حاجة لذلك
plt.grid(True)  # إضافة شبكة للمساعدة في القراءة
plt.tight_layout()  # تحسين التباعد
plt.show()

# %%
brand_cost = cars.groupby('brand')['total cost'].mean().reset_index()

# %%
sns.lineplot(data = brand_cost , x = 'brand' , y = 'total cost' , marker = 'o')
# Out:
# <Axes: xlabel='brand', ylabel='total cost'>

# %%
brand_model = cars.groupby(['brand','model'])['total cost'].mean().reset_index()

# %%
g = sns.FacetGrid(brand_model, col='brand', col_wrap=4, height=4, sharex=False, sharey=False, despine=True)
g.map(sns.barplot, 'model', 'total cost', order=brand_model['model'].unique(), palette='viridis')

for ax in g.axes.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
brand_transmission = cars.groupby(['brand','transmission'])['fuelType'].count().reset_index()

# %%
brand_transmission.rename(columns={'fuelType':'count'}, inplace=True)

# %%
sns.barplot(data = brand_transmission, x = 'brand', y = 'count', hue = 'transmission')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='brand', ylabel='count'>

# %%
sns.barplot(data = brand_fuelType, x = 'brand', y = 'total cost', hue = 'fuelType')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.lineplot(data = fuelType_cost, x = 'fuelType', y ='total cost', marker = 'o')
# Out:
# <Axes: xlabel='fuelType', ylabel='total cost'>

# %%
sns.lineplot(data = transmission_cost, x = 'transmission', y = 'total cost', marker = 'o')
# Out:
# <Axes: xlabel='transmission', ylabel='total cost'>

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
cars['brand'] = encoder.fit_transform(cars['brand'])

# %%
cars['brand']
# Out:
# 0       3
# 1       7
# 2       0
# 3       8
# 4       5
#        ..
# 4955    4
# 4956    1
# 4957    8
# 4958    0
# 4959    4
# Name: brand, Length: 4960, dtype: int64

# %%
cars['model'] = encoder.fit_transform(cars['model'])

# %%
cars['transmission'] = encoder.fit_transform(cars['transmission'])

# %%
cars['fuelType'] = encoder.fit_transform(cars['fuelType'])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
cars['mileage'] = scaler.fit_transform(cars[['mileage']])
cars['engineSize'] = scaler.fit_transform(cars[['engineSize']])
cars['mpg'] = scaler.fit_transform(cars[['mpg']])
cars['year'] = scaler.fit_transform(cars[['year']])

# %%
y = cars['total cost']
x = cars.drop('total cost', axis = 1)

# %%
y
# Out:
# 0       32140
# 1        7825
# 2       59135
# 3       13029
# 4       17135
#         ...
# 4955    18124
# 4956    29045
# 4957     9028
# 4958    23343
# 4959    15050
# Name: total cost, Length: 4960, dtype: int64

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
selector = SelectKBest(score_func = f_regression, k =8)
x_new = selector.fit_transform(x,y)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
MAE =mean_absolute_error(pred,y_test)
MAE
# Out:
# 6289.527179673258

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,pred)
r2
# Out:
# 0.6708784698877048
